# %% [markdown]
# <a href="https://colab.research.google.com/github/khonkaen-iot/defect-detection/blob/main/EP4_YOLO_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.9/605.9 kB 6.8 MB/s eta 0:00:00

# %%
# !nvidia-smi
# Out:
# Fri Jul 21 01:10:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from ultralytics import YOLO

# %%
# !wget https://app.roboflow.com/ds/NodISe187h?key=qAXI4LGPFu
# Out:
# --2023-07-21 01:10:25--  https://app.roboflow.com/ds/NodISe187h?key=qAXI4LGPFu
# Resolving app.roboflow.com (app.roboflow.com)... 151.101.1.195, 151.101.65.195
# Connecting to app.roboflow.com (app.roboflow.com)|151.101.1.195|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/roboflow-platform-exports/a5F4EAcDzodLv6bGiuVbG1S11Zq1/L9rjXfkyT8nTBF0SgZvM/1/yolov8.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=481589474394-compute%40developer.gserviceaccount.com%2F20230721%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230721T011025Z&X-Goog-Expires=901&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# ...

# %%
# !unzip /content/NodISe187h?key=qAXI4LGPFu
# Out:
# Archive:  /content/NodISe187h?key=qAXI4LGPFu
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: train/
#    creating: train/images/
#  extracting: train/images/000_png.rf.00ba8a26a5684c89d40cb1e2d1f2f3aa.jpg
#  extracting: train/images/000_png.rf.0db1fcd941666dd126c0e6a9996c47eb.jpg
#  extracting: train/images/000_png.rf.1f7038cb8a8a1b5e62efd9dc511e7a8d.jpg
#  extracting: train/images/000_png.rf.2e165aeda7014ec3c88e06c9c8ea3432.jpg
#  extracting: train/images/000_png.rf.59f492be804d24840e75e6d440b3daf2.jpg
#  extracting: train/images/000_png.rf.5e1309e9a67cd86aad90e1538016b011.jpg
#  extracting: train/images/000_png.rf.7ac7288d7b5517b76ce2615e713a954f.jpg
#  extracting: train/images/000_png.rf.8ed9378d7ba4dfa9c4746819da649d85.jpg
#  extracting: train/images/000_png.rf.9f7a117ce41019692b76a791b2795ccf.jpg
#  extracting: train/images/000_png.rf.a4d1649f4b66c64e7f3cd2a989a35df2.jpg
# ...

# %%
# !yolo detect train data=/content/data.yaml model=yolov8m.pt epochs= 100 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 363MB/s]
# Ultralytics YOLOv8.0.139 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Run inference on an image with YOLOv8n
# !yolo predict model=/content/runs/detect/train/weights/best.pt source=/content/valid/images
# Out:
# Ultralytics YOLOv8.0.139 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842655 parameters, 0 gradients
#
# image 1/34 /content/valid/images/000_png.rf.d74374315e09babee371193f1972eee8.jpg: 640x640 1 scratch_head, 37.2ms
# image 2/34 /content/valid/images/001_png.rf.e1e085084e11b4ecfe541044f15fdd72.jpg: 640x640 1 scratch_neck, 37.0ms
# image 3/34 /content/valid/images/001_png.rf.e5d9eceb3241f52722b5e6979bac2bd5.jpg: 640x640 (no detections), 36.9ms
# image 4/34 /content/valid/images/002_png.rf.c6ba59f0f655db346579a4e0f75596ec.jpg: 640x640 1 thread_top, 31.6ms
# image 5/34 /content/valid/images/004_png.rf.1bf5b7b6bb34a94ec1a3d9a1e250e837.jpg: 640x640 (no detections), 28.1ms
# image 6/34 /content/valid/images/004_png.rf.4d2f696a301f8af8a8a7de8bc6b643d2.jpg: 640x640 1 scratch_neck, 28.1ms
# image 7/34 /content/valid/images/004_png.rf.7dbffce98708785aa047c927be870a76.jpg: 640x640 1 thread_top, 28.0ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import gdown

# Specify the source directory and destination directory in Google Drive
source_directory = '/content/runs/detect'
destination_directory = '/content/drive/MyDrive/Yolo_screw'

# Copy all files from the source directory to the destination directory
shutil.copytree(source_directory, destination_directory)
# Out:
# '/content/drive/MyDrive/Yolo_screw'
